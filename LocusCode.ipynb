# %% [markdown]
# # Brief Explanation

# %% [markdown]
# **Brief Explanation:**
#
# To work, you must have an unchanged copy of the Google Form responses sheet saved to your My Drive.
#
#
# ---
#
#
# Familiarize yourself with the code. Look through and make sure you have an idea of how it works.
#
#
# ---
#
#
# Type the the name of the survey response file in the cell below. Run the cell.
#  Run the load in folder.
#
#
# ---
#
#
# To execute code, click the triangle in a circle that appears when hovering over the bracket box [ ] to the left of the italicized "cells hidden" message. Individual cells can also be run by pressing shift enter.
#
#
#
#
# ---
#
# You will have to run the functions in the preceding folders to use later analysis. Run the function folder but you don't have to run the main.
#
#
# ---
#
#
# Despite response validation, layers of error handling, and several iterations of testing, you may well get nonsensical results or run-time errors. Compile time errors are even possible. Most immediately, survey respondants may not have followed directions or perhaps they made typos. Encountering problems in the Routing Analysis may be due to the OSRM API usage limits. The Clustering Analysis will be extremely slow if using real street distance, but that option is still there for proof of concept and small sample sizes.
#
#
# ---
#
#
# If you run into any problems, or are just curious, please see our Documentation. Futhermore, as you will find, the code is commented throughout. Lastly, I encourage you to implement your own fixes and improvements, and please feel free to share them with me at js0735@princeton.edu.

# %% [markdown]
# # Functions

# %% [markdown]
# #### Load-in and Access

# %%
import pandas as pd
from google.colab import drive

def load_in(file_name):

  #to import your comma seperated value (.csv file) data frame from google drive

  drive.mount('/content/drive', force_remount=True)

  path = '/content/drive/MyDrive/'
  file = path + file_name
  df = pd.read_csv(file, header=0)

  new_headers = ['Time', 'Level', 'Department', "Years w/ Company", "Lat and Long", "Pincode", "Commute Time", "Commute Method", "Age", "Gender", "Marraige", "Children", "Residence", "Daycare Preference", "Shifting Preference", "Pincode Preference", "Salary / WFO Preference", "Managed by Indiqube?", "Indiqube Rating", "Frequency of app", "Usefulness of app", "Sentiment", "Suggestions"]


  df.columns = new_headers
  return df

# %%
def get_column_number(column_name, df):
    try:
        column_number = df.columns.get_loc(column_name)
        return column_number
    except KeyError:
        print(f"Error: Column '{column_name}' not found in the DataFrame.")
        return None

# %%
def get_value(df,column,row):
  return df[list(df.keys())[column]][row]

# %% [markdown]
# #### Scatter Plot and Heat Map

# %%
def numeric(df):
  num_dict = {'Man' : 1, "Woman" : 0, "Yes" : 1, "No" : 0}
  df_copy = df.copy()
  columns = ["Gender", "Marraige"]

  for column in columns:
        if column in df_copy.columns:
            df_copy[column] = df_copy[column].replace(num_dict)
        else:
            raise KeyError(f"Column '{column}' not found in DataFrame")

  columnnums_to_drop = [0,1,2,4,5,7,12,15,17,21,22]
  columns_to_drop = []

  for colnum in columnnums_to_drop:
    columns_to_drop.append(list(df.keys())[colnum])

  # Drop the specified columns

  df_copy.drop(columns=columns_to_drop, inplace=True)
  return df_copy

# %%
import seaborn as sns
def pairplot(num_df):
  sns.pairplot(num_df)

# %%
from matplotlib import rcParams
def heatmap(num_df):
  rcParams['figure.figsize'] = 8,8
  correlation_matrix = num_df.corr().round(2)
  sns.heatmap(data=correlation_matrix, annot=True)

# %% [markdown]
# #### Bar Grapher

# %%
### Helper function to the bar grapher

def filter_and_calculate_average_target(df, target_dict, target_val):
    # Create a boolean mask for filtering
    mask = pd.Series(True, index=df.index)

    # Apply filters for each column and target entry
    for column, target in target_dict.items():
        mask &= df[column] == target

    # Filter the DataFrame
    filtered_df = df[mask]

    # Calculate average effective rent
    avg_target_val = filtered_df[target_val].mean()
    count = filtered_df[target_val].count()

    return round(avg_target_val,2), count

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def make_bargraph_for_this_center(df, column, target_val, location):
    # Calculate averages and counts
    averages = []
    counts = []
    categories = []
    unique_in_column = df[column].unique()

    for category in unique_in_column:
        condition = {column: category}
        avg, count = filter_and_calculate_average_target(df, condition, target_val)
        averages.append(avg)
        counts.append(count)
        categories.append(category)

    # Create a DataFrame from the results
    result_df = pd.DataFrame({column: categories, 'Average': averages, 'Count': counts})

    # Sort the DataFrame if the category is numerical
    if pd.api.types.is_numeric_dtype(result_df[column]):
        result_df = result_df.sort_values(by=column)

    # Create the plot
    plt.figure(figsize=(12, 6))
    ax = sns.barplot(x=column, y='Average', data=result_df)

    # Add average and count labels on each bar
    for i, bar in enumerate(ax.patches):
        height = bar.get_height()
        avg = result_df['Average'].iloc[i]
        count = result_df['Count'].iloc[i]

        ax.text(bar.get_x() + bar.get_width()/2., height,
                f'Avg: {avg:.2f}\nCount: {count}',
                ha='center', va='bottom', fontsize=8)




    # Define your custom color palette with hex values
    custom_palette = {
        'primary': '#1ececa',    # Example: indiqube light blue
        'secondary': '#0b109f',  # Example: indiqube dark blue
        'accent': '#0000fa'      # Example: another blue
    }

    # Set the style
    sns.set_style("whitegrid")

    # Set the custom color palette
    sns.set_palette(list(custom_palette.values()))

    # If you want to set specific elements to use specific colors:
    plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_palette.values())

    # Customize the plot
    plt.title(f'Average {target_val} by {column} (with counts) for ' + location)
    plt.xlabel(column)
    plt.ylabel(f'Average {target_val}')

    # Rotate x-axis labels if there are many categories
    if len(unique_in_column) > 10:
        plt.xticks(rotation=45, ha='right')

    plt.tight_layout()
    plt.show()

# Note: This function assumes filter_and_calculate_avg_target is defined elsewhere
# and returns both the average and the count

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def make_bargraph(df, column, target_val):
    # Calculate averages and counts
    averages = []
    counts = []
    categories = []
    unique_in_column = df[column].unique()

    for category in unique_in_column:
        condition = {column: category}
        avg, count = filter_and_calculate_average_target(df, condition, target_val)
        averages.append(avg)
        counts.append(count)
        categories.append(category)

    # Create a DataFrame from the results
    result_df = pd.DataFrame({column: categories, 'Average': averages, 'Count': counts})

    # Sort the DataFrame if the category is numerical
    if pd.api.types.is_numeric_dtype(result_df[column]):
        result_df = result_df.sort_values(by=column)

    # Create the plot
    plt.figure(figsize=(12, 6))
    ax = sns.barplot(x=column, y='Average', data=result_df)

    # Add average and count labels on each bar
    for i, bar in enumerate(ax.patches):
        height = bar.get_height()
        avg = result_df['Average'].iloc[i]
        count = result_df['Count'].iloc[i]

        ax.text(bar.get_x() + bar.get_width()/2., height,
                f'Avg: {avg:.2f}\nCount: {count}',
                ha='center', va='bottom', fontsize=8)




    # Define your custom color palette with hex values
    custom_palette = {
        'primary': '#1ececa',    # Example: indiqube light blue
        'secondary': '#0b109f',  # Example: indiqube dark blue
        'accent': '#0000fa'      # Example: another blue
    }

    # Set the style
    sns.set_style("whitegrid")

    # Set the custom color palette
    sns.set_palette(list(custom_palette.values()))

    # If you want to set specific elements to use specific colors:
    plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_palette.values())

    # Customize the plot
    plt.title(f'Average {target_val} by {column} (with counts)')
    plt.xlabel(column)
    plt.ylabel(f'Average {target_val}')

    # Rotate x-axis labels if there are many categories
    if len(unique_in_column) > 10:
        plt.xticks(rotation=45, ha='right')

    plt.tight_layout()
    plt.show()

# Note: This function assumes filter_and_calculate_avg_target is defined elsewhere
# and returns both the average and the count

# %% [markdown]
# #### Standarize Locations

# %%
def parse_number_pair(string):
    try:
        # Split the string at the comma
        num1, num2 = string.split(',')
        # Convert both parts to floats and return as a tuple
        return (float(num1.strip()), float(num2.strip()))
    except ValueError:
        # If there's an error in parsing, return None or raise an exception
        # return None  # or
        raise ValueError("Invalid format")

# %%
def get_points(df):
  points = list(df[list(df.keys())[4]])

  latlongs = []
  for point in points:
    latlongs.append(parse_number_pair(point))

  lat = 0
  longi = 0
  for latlong in latlongs:
    lat += latlong[0]
    longi += latlong[1]

  lat = lat / len(latlongs)
  longi = longi / len(latlongs)

  geocenter = (lat,longi)

  return latlongs, geocenter

# %% [markdown]
# #### OSRM Routing

# %%
# Gets route data from OSRM
# The function returns geometry, time, distance
# geometry is a dict with 'coordinates' as the key and a list of lat-long points as the value
# time is in seconds, and accounts for average traffic and turns but not time of day
# distance is in meters

import requests
def get_route_info(start, end):
  # Format start and end points
  start_str = f"{start[1]},{start[0]}"
  end_str = f"{end[1]},{end[0]}"

  # Combine start and end into a single string
  waypoints_str = f"{start_str};{end_str}"

  url = f"http://router.project-osrm.org/route/v1/driving/{waypoints_str}?geometries=geojson"


  # Make the request
  response = requests.get(url)
  if response.status_code != 200:
      raise Exception(f"Error: Received response code {response.status_code} from OSRM server")

  data = response.json()


  if 'routes' in data:
      routeinfo = data['routes']

      if routeinfo and 'geometry' in routeinfo[0]:
          geometry = routeinfo[0]['geometry']
          time = routeinfo[0]['duration']
          distance = routeinfo[0]['distance']
          if not distance:
            print("none")

      else:
          print("response does not contain info")
  else:
      print("No 'routes' key in data")

  return geometry, time, distance

# %%
# returns a list of dicts.
# each dict contains geometry, time, and distance

def get_route_infos(df,gathering_point):
  points, geocenter = get_points(df)

  route_infos = []

  for point in points:
    geometry, time, distance = get_route_info(point, gathering_point)
    route_info = {
        'geometry': geometry,
        'time': time,
        'distance': distance
    }
    route_infos.append(route_info)

  return route_infos

# %%
def create_routes_dataframe(list_of_dicts):
    # Create the DataFrame directly from the list of dictionaries
    df = pd.DataFrame(list_of_dicts)

    # Ensure the DataFrame has the desired columns in the correct order
    desired_columns = ['geometry', 'time', 'distance']
    df = df.reindex(columns=desired_columns)

    return df

# %% [markdown]
# #### Commute Analysis

# %%
# Total, Mean, Median : Time
# Total, Mean, Median : Distance
# Total + Error Emissions

# See the assumption made throught out, including estimations for kgs per km for modes of transport and 50, 5-day work weeks each year with round trip commutes each work day
# also the traffic multiplier in Bengaluru during rush hour seems to be about x2 to the OSRM optimal times, so that's what I used

import statistics

def commute_analysis(combined_df, office_name):


  methods = list(combined_df['Commute Method'])
  times = list(combined_df['time'])
  distances = list(combined_df['distance'])

  total_time = sum(times) * 2 * 2
  mean_time = total_time / len(times) / 2
  median_time = statistics.median(times) * 2

  total_distance = sum(distances)
  mean_distance = total_distance / len(distances)
  median_distance = statistics.median(distances)


  # these dictionaries are my own estimates, feel free to change
  ratios = {
    "Two wheeler EV": 0.02,
    "Two wheeler non EV": 0.04,
    "Personal car EV": 0.03,
    "Personal car non EV": 0.12,
    "Bus": 0.05,
    "Metro": 0.03,
    "Auto": 0.04,
    "Namma Yatri, Uber, Rapido, etc.": 0.12
}
  ratios["Combination of these"] = sum(ratios.values()) / len(ratios.values())

  uncertainties = {
    "Two wheeler EV": 0.002,
    "Two wheeler non EV": 0.004,
    "Personal car EV": 0.003,
    "Personal car non EV": 0.012,
    "Bus": 0.005,
    "Metro": 0.003,
    "Auto": 0.004,
    "Namma Yatri, Uber, Rapido, etc.": 0.012
}

  uncertainties["Combination of these"] = ratios["Combination of these"] / 10

  # Round to r decimal places
  r = 2

  # Calculate annual emissions and error margin
  annual_factor = 50 * 5 * 2  # Assuming 50 weeks, 5 days a week, 2 ways per day

  total_emissions = 0
  emissions_error_margin  = 0

  i = 0
  for distance in distances:
    total_emissions += distance / 1000 * ratios[methods[i]]
    emissions_error_margin  += distance / 1000 * uncertainties[methods[i]]
    i+= 1


  data = {
      "For " + office_name: [
          total_time / 60,
          mean_time / 60,
          median_time / 60,
          total_distance / 1000,
          mean_distance / 1000,
          median_distance / 1000,
          total_emissions * annual_factor,
          emissions_error_margin * annual_factor
      ]
  }

  # Round all values to r decimal places
  data["For " + office_name] = [round(x, r) for x in data["For " + office_name]]

  title = {
      "Measure": [
          "total time (minutes each day)",
          "mean time (minutes one way)",
          "median time (minutes one way)",
          "total distance (kilometers one way)",
          "mean distance (kilometers)",
          "median distance (kilometers)",
          "total emissions (kgs per year)",
          "emissions error margin (kgs per year)"
      ]
  }

  # Create DataFrame
  df = pd.DataFrame({**title, **data})

  return df

# %% [markdown]
# #### Clustering Algorithms

# %% [markdown]
# ##### K-Means

# %%
### non-weighted Kmeans clustering

import numpy as np
from sklearn.cluster import KMeans

def Kmeans(codes):
  array_2d = np.array([np.array(pair) for pair in codes])
  kmeans = KMeans(n_clusters=2, random_state=3, init='k-means++')
  kmeans.fit(codes)
  labels = kmeans.labels_
  labels = list(labels)
  centroids = kmeans.cluster_centers_

  return labels, centroids

# %% [markdown]
# ##### Weighted K-Means

# %%
def standard_distance(point1, point2):
    return np.sqrt((point1[0] - point2[0])**2 + (point1[1] - point2[1])**2)

# %%
# Weighted K-means clustering algorithm
# an adapted Claude AI function:

import numpy as np
from typing import List, Tuple, Callable

def claudes_weighted_kmeans(
    points: List[Tuple[float, float]],
    weights: List[float],
    n_clusters: int,
    max_iterations: int,
    n_repetitions: int,
    distance_func: Callable[[Tuple[float, float], Tuple[float, float]], float]
) -> Tuple[List[int], List[Tuple[float, float]]]:

    points = np.array(points)
    weights = np.array(weights)

    best_labels = None
    best_centroids = None
    best_inertia = float('inf')

    for _ in range(n_repetitions):
        # Randomly initialize centroids
        centroids = points[np.random.choice(len(points), n_clusters, replace=False)]

        for _ in range(max_iterations):
            # Assign points to nearest centroid
            distances = np.array([[distance_func(point, centroid) for centroid in centroids] for point in points])
            labels = np.argmin(distances, axis=1)

            # Update centroids
            new_centroids = []
            for i in range(n_clusters):
                cluster_points = points[labels == i]
                cluster_weights = weights[labels == i]
                if len(cluster_points) > 0:
                    new_centroids.append(np.average(cluster_points, axis=0, weights=cluster_weights))
                else:
                    new_centroids.append(centroids[i])

            new_centroids = np.array(new_centroids)

            # Check for convergence
            if np.all(centroids == new_centroids):
                break

            centroids = new_centroids

        # Calculate inertia (weighted sum of squared distances)
        inertia = sum(weights[i] * distance_func(points[i], centroids[labels[i]])**2 for i in range(len(points)))

        # Update best solution if current solution is better
        if inertia < best_inertia:
            best_inertia = inertia
            best_labels = labels
            best_centroids = centroids

    return best_labels.tolist(), best_centroids.tolist()

# %% [markdown]
# ####  Plotting Folium Maps

# %% [markdown]
# ##### Plot Employees

# %%
import folium

def plot_employees(df,coloring, pop_up, description, map_theme):

  latlongs, center = get_points(df)

  if (map_theme == 'clean'):
    # URL for the custom tile layer
    tile_url = 'http://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}.png'

    # Attribution for the custom tile layer
    tile_attribution = 'Map tiles by CartoDB, under CC BY 3.0. Data by OpenStreetMap, under ODbL.'

    # Create a map with the custom tile layer
    mymap = folium.Map(location=center, zoom_start=12, width='100%', height='500px', tiles=tile_url, attr=tile_attribution)

  else:
     mymap = folium.Map(location=center, zoom_start=12, width='100%', height='500px')

  popup_column = get_column_number(pop_up, df)
  description_column = get_column_number(description, df)
  color_column = get_column_number(coloring, df)

  # Get unique categories from the target column
  categories = df[coloring].unique()

  # List of predefined colors
  colors = ['pink', 'cadetblue', 'darkgreen', 'gray', 'darkblue', 'lightblue', 'darkpurple',
              'red', 'lightgray', 'beige', 'green', 'blue', 'darkred', 'black', 'purple',
              'orange', 'lightred', 'lightgreen',]

  # Create a color map for categories
  # Ensure we have enough colors
  if len(categories) > len(colors):
      raise ValueError(f"Not enough unique colors for {len(categories)} categories. Only {len(colors)} colors available.")

  # Create a color map for categories
  selected_colors = random.sample(colors, len(categories))
  color_map = dict(zip(categories, selected_colors))

  # Add points to the map
  row = 0
  for latlong in latlongs:
    folium.Marker(
        location=latlong,
        popup= get_value(df, popup_column, row),
        tooltip= get_value(df, description_column, row),
        icon=folium.Icon(color=color_map[get_value(df, color_column, row)])
    ).add_to(mymap)
    row += 1

  # Add a legend
  legend_html = '''
  <div style="position: fixed; bottom: 50px; left: 50px; width: 300px; height: 120px;
  border:2px solid grey; z-index:9999; font-size:14px;
  ">&nbsp;<b>Legend</b><br>
  '''
  for category, color in color_map.items():
      legend_html += f"&nbsp;<i class='fa fa-map-marker fa-2x' style='color:{color}'></i>&nbsp;{category}<br>"
  legend_html += '</div>'
  mymap.get_root().html.add_child(folium.Element(legend_html))


  return mymap

# %% [markdown]
# ##### Plot Employees UI

# %%
### User Interface to show what's available to plot
import ipywidgets as widgets
from IPython.display import display

def create_employee_map_ui(df, plot_employees_func):
    # Define options for each dropdown
    coloring_options = list(df.keys())
    popup_options = list(df.keys())
    description_options = list(df.keys())
    theme_options = ["standard", "clean"]

    # Create dropdown widgets
    coloring_dropdown = widgets.Dropdown(options=coloring_options, description='Coloring:', value='Level')
    popup_dropdown = widgets.Dropdown(options=popup_options, description='Pop-up:', value='Gender')
    description_dropdown = widgets.Dropdown(options=description_options, description='Description:', value='Age')
    theme_dropdown = widgets.Dropdown(options=theme_options, description='Theme:', value='clean')

    # Create output widget to display the map
    output = widgets.Output()

    # Function to update the map
    def update_map(*args):
        with output:
            output.clear_output(wait=True)
            m = plot_employees_func(
                df,
                coloring_dropdown.value,
                description_dropdown.value,
                popup_dropdown.value,
                theme_dropdown.value
            )
            display(m)

    # Observe changes for all dropdowns
    coloring_dropdown.observe(update_map, names='value')
    popup_dropdown.observe(update_map, names='value')
    description_dropdown.observe(update_map, names='value')
    theme_dropdown.observe(update_map, names='value')

    # Create a vertical box layout for dropdowns
    dropdown_vbox = widgets.VBox([coloring_dropdown, popup_dropdown, description_dropdown, theme_dropdown])

    # Create a vertical box layout for both dropdowns and output
    main_vbox = widgets.VBox([dropdown_vbox, output])

    # Initial map update
    update_map()

    return main_vbox

# %% [markdown]
# ##### Plot Routes

# %%
def add_routes(mymap, route_geometries,col):
    # Add polylines for each route
    for route_geometry in route_geometries:
        folium.PolyLine(
            locations=[list(reversed(coord)) for coord in route_geometry],
            color=col,
            weight=5
        ).add_to(mymap)

    return mymap

# %%
def create_route_map(routes_df, center, map_theme):

  if (map_theme == 'clean'):
    # URL for the custom tile layer
    tile_url = 'http://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}.png'

    # Attribution for the custom tile layer
    tile_attribution = 'Map tiles by CartoDB, under CC BY 3.0. Data by OpenStreetMap, under ODbL.'

    # Create a map with the custom tile layer
    mymap = folium.Map(location=center, zoom_start=12, tiles=tile_url, attr=tile_attribution)

  else:
    mymap = folium.Map(location=center, zoom_start=12)

  routes = []

  for index, row in routes_df.iterrows():

    point = (row['geometry']['coordinates'][0][1], row['geometry']['coordinates'][0][0])

    folium.Marker(location=point, popup=row['time'], icon=folium.Icon(color='blue')).add_to(mymap)

    routes.append(row['geometry']['coordinates'])

    mymap = add_routes(mymap,routes, "blue")


  folium.Marker(center, popup=f'center', icon=folium.Icon(color='red')).add_to(mymap)

  return mymap

# %% [markdown]
# ##### Plot Clusters

# %%
### Plot Clusters

import folium
def plot_clusters(points, center, labels, centroids, map_theme):

  array_2d = np.array([np.array(pair) for pair in points])

  if (map_theme == 'clean'):
    # URL for the custom tile layer
    tile_url = 'http://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}.png'

    # Attribution for the custom tile layer
    tile_attribution = 'Map tiles by CartoDB, under CC BY 3.0. Data by OpenStreetMap, under ODbL.'

    # Create a map with the custom tile layer
    cluster_map = folium.Map(location=center, zoom_start=12, tiles=tile_url, attr=tile_attribution)

  else:
     cluster_map = folium.Map(location=center, zoom_start=12)



  colors = [
        'red', 'blue', 'green', 'purple', 'orange', 'darkred',
        'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue',
        'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen',
        'gray', 'black', 'lightgray'
    ]


  # Add markers for each point
  for i in range(len(array_2d)):
      folium.Marker(
          location=array_2d[i],
          popup=f'employee{i}',
          icon=folium.Icon(color=colors[labels[i]])
      ).add_to(cluster_map)

  # Add markers for centroids
  for i in range(len(centroids)):
      folium.Marker(centroids[i], popup=f'Centroid {i}', icon=folium.Icon(color='black')).add_to(cluster_map)

  # Display the map
  return cluster_map

# %% [markdown]
# ##### Plot by Category

# %%
import folium
from folium.plugins import MarkerCluster
import random

def plot_by_category(df, target_column, geocenter, zoom_start,map_theme):
    location_column = 'Lat and Long'

    # Create a map
    if (map_theme == 'clean'):
      # URL for the custom tile layer
      tile_url = 'http://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}.png'

      # Attribution for the custom tile layer
      tile_attribution = 'Map tiles by CartoDB, under CC BY 3.0. Data by OpenStreetMap, under ODbL.'

      # Create a map with the custom tile layer
      m = folium.Map(location=geocenter, zoom_start=12, tiles=tile_url, attr=tile_attribution)

    else:
      m = folium.Map(location=geocenter, zoom_start=12)


    # Create a MarkerCluster
    # marker_cluster = MarkerCluster().add_to(m)

    # Get unique categories from the target column
    categories = df[target_column].unique()

    # List of predefined colors
    colors = ['pink', 'cadetblue', 'darkgreen', 'gray', 'darkblue', 'lightblue', 'darkpurple',
              'red', 'lightgray', 'beige', 'green', 'blue', 'darkred', 'black', 'purple',
              'orange', 'lightred', 'lightgreen',]

    # Create a color map for categories
    # Ensure we have enough colors
    if len(categories) > len(colors):
        raise ValueError(f"Not enough unique colors for {len(categories)} categories. Only {len(colors)} colors available.")

    # Create a color map for categories
    selected_colors = random.sample(colors, len(categories))
    color_map = dict(zip(categories, selected_colors))

    # Dictionary to store sum of coordinates and count for each category
    category_coords = {cat: {'sum': [0.0, 0.0], 'count': 0} for cat in categories}

    # Add markers for each point
    for idx, row in df.iterrows():
        lat, lon = parse_number_pair(row[location_column])
        category = row[target_column]
        color = color_map[category]

        folium.Marker(
            location=[lat, lon],
            popup=f"{target_column}: {category}",
            icon=folium.Icon(color=color, icon='info-sign')
        ).add_to(m)

        # Update sum and count for category
        category_coords[category]['sum'][0] += lat
        category_coords[category]['sum'][1] += lon
        category_coords[category]['count'] += 1

    # Add center of mass markers for each category
    for category, data in category_coords.items():
        if data['count'] > 0:
            center_of_mass = [data['sum'][0] / data['count'], data['sum'][1] / data['count']]
            folium.Marker(
                location=center_of_mass,
                popup=f"Center of Mass for {category}",
                icon=folium.Icon(color=color_map[category], icon='star')
            ).add_to(m)

    # Add a legend
    legend_html = '''
    <div style="position: fixed; bottom: 50px; left: 50px; width: 300px; height: 120px;
    border:2px solid grey; z-index:9999; font-size:14px;
    ">&nbsp;<b>Legend</b><br>
    '''
    for category, color in color_map.items():
        legend_html += f"&nbsp;<i class='fa fa-map-marker fa-2x' style='color:{color}'></i>&nbsp;{category}<br>"
    legend_html += '</div>'
    m.get_root().html.add_child(folium.Element(legend_html))

    return m

# Example usage:
# Assuming df is your DataFrame with columns 'Location' (tuple of lat, long) and 'Category'
# m = create_map_with_markers(df, 'Location', 'Category')
# m.save('map.html')

# %% [markdown]
# # User Interface

# %% [markdown]
# ## Load In

# %%
surveyfilename = "July23.csv"

# %%
df = load_in(surveyfilename)
# df.head()
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Basic Tools

# %% [markdown]
# ### Heatmap and Pairplot

# %%
num_df = numeric(df)
# num_df.head()

# %%
heatmap(num_df)

# %%
pairplot(num_df)

# %% [markdown]
# ### Map and Graph tools

# %%
### This is a nice way to display employee information on a map.

coloring = "Level"
pop_up = "Gender"
description = "Age"
theme = "clean"

# theme is standard or clean

m = plot_employees(df, coloring, description, pop_up, theme)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5156b340edd72f8eb85f80dfdf6c9ef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#   &lt;div style=&quot;position: fixed; bottom: 50px; left: 50px; width: 300px; height: 120px;
#   border:2px solid grey; z-index:9999; font-size:14px;
#   &quot;&gt;&amp;nbsp;&lt;b&gt;Legend&lt;/b&gt;&lt;br&gt;
#   &amp;nbsp;&lt;i class=&#x27;fa fa-map-marker fa-2x&#x27; style=&#x27;color:darkblue&#x27;&gt;&lt;/i&gt;&amp;nbsp;Non executive&lt;br&gt;&amp;nbsp;&lt;i class=&#x27;fa fa-map-marker fa-2x&#x27; style=&#x27;color:pink&#x27;&gt;&lt;/i&gt;&amp;nbsp;Mid level executive or manager&lt;br&gt;&amp;nbsp;&lt;i class=&#x27;fa fa-map-marker fa-2x&#x27; style=&#x27;color:red&#x27;&gt;&lt;/i&gt;&amp;nbsp;Upper level executive, VP, etc.&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5156b340edd72f8eb85f80dfdf6c9ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5156b340edd72f8eb85f80dfdf6c9ef = L.map(
#                 &quot;map_c5156b340edd72f8eb85f80dfdf6c9ef&quot;,
#                 {
#                     center: [12.937899282876856, 77.62113070481908],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_beb9a7fb3d724746ac211e209112f215 = L.tileLayer(
#                 &quot;http://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by CartoDB, under CC BY 3.0. Data by OpenStreetMap, under ODbL.&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_beb9a7fb3d724746ac211e209112f215.addTo(map_c5156b340edd72f8eb85f80dfdf6c9ef);
#
#
#             var marker_9f6d1072d713dbedb48cc7aac9bdd74e = L.marker(
#                 [12.929219184155466, 77.62771079999999],
#                 {}
#             ).addTo(map_c5156b340edd72f8eb85f80dfdf6c9ef);
#
#
#             var icon_890cff670761469f4514e3f3fb954cbc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9f6d1072d713dbedb48cc7aac9bdd74e.setIcon(icon_890cff670761469f4514e3f3fb954cbc);
#
#
#         var popup_5116116959302046f92c71bbcf235494 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b9d2c1915657756737b091ea2b67bc82 = $(`&lt;div id=&quot;html_b9d2c1915657756737b091ea2b67bc82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;20&lt;/div&gt;`)[0];
#                 popup_5116116959302046f92c71bbcf235494.setContent(html_b9d2c1915657756737b091ea2b67bc82);
#
#
#
#         marker_9f6d1072d713dbedb48cc7aac9bdd74e.bindPopup(popup_5116116959302046f92c71bbcf235494)
#         ;
#
#
#
#
#             marker_9f6d1072d713dbedb48cc7aac9bdd74e.bindTooltip(
#                 `&lt;div&gt;
#                      Man
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_984cb9117433fdc7c11d08a97b41e277 = L.marker(
#                 [12.950795517102389, 77.61704047253774],
#                 {}
#             ).addTo(map_c5156b340edd72f8eb85f80dfdf6c9ef);
#
#
#             var icon_46a56b2447c39763e5fd5a3e84d6aa20 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_984cb9117433fdc7c11d08a97b41e277.setIcon(icon_46a56b2447c39763e5fd5a3e84d6aa20);
#
#
#         var popup_2b831c171a8ec6ade78929e4cd9803e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6cf80816cc15bdcb3b0d47b70dbf24d2 = $(`&lt;div id=&quot;html_6cf80816cc15bdcb3b0d47b70dbf24d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;24&lt;/div&gt;`)[0];
#                 popup_2b831c171a8ec6ade78929e4cd9803e6.setContent(html_6cf80816cc15bdcb3b0d47b70dbf24d2);
#
#
#
#         marker_984cb9117433fdc7c11d08a97b41e277.bindPopup(popup_2b831c171a8ec6ade78929e4cd9803e6)
#         ;
#
#
#
#
#             marker_984cb9117433fdc7c11d08a97b41e277.bindTooltip(
#                 `&lt;div&gt;
#                      Man
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e472433babc9a3e24ed7ca7ddaafa446 = L.marker(
#                 [12.940321422890475, 77.58458798397496],
#                 {}
#             ).addTo(map_c5156b340edd72f8eb85f80dfdf6c9ef);
#
#
#             var icon_eb4f14d80e0e6aea6ecb4ccc8ce167e2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e472433babc9a3e24ed7ca7dd

# %%
ui = create_employee_map_ui(df, plot_employees)
display(ui)
# Out:
# VBox(children=(VBox(children=(Dropdown(description='Coloring:', index=1, options=('Time', 'Level', 'Department…

# %%
# see all 22 variables under More Information
categories = "Department"
value = "Age"
make_bargraph(df, categories, value)

# %% [markdown]
# ## Routing Tools

# %% [markdown]
# ### Choose Location

# %%
# replace center with copy and pasted office longitude and latitude
points, geocenter = get_points(df)

office = geocenter

route_infos = []

route_infos = get_route_infos(df, office)

routes_df = create_routes_dataframe(route_infos)

combined_df1 = pd.concat([df, routes_df], axis=1)
combined_df1.reset_index(drop=True, inplace=True)

# %%
office = (12.943860555628737, 77.64203857962248)

route_infos = []

route_infos = get_route_infos(df, office)

routes_df = create_routes_dataframe(route_infos)

combined_df2 = pd.concat([df, routes_df], axis=1)
combined_df2.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Plot Commute Flower

# %%
route_map = create_route_map(routes_df, office, 'clean')
route_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3730749e4ee5c329f7bb914e57cc3409 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3730749e4ee5c329f7bb914e57cc3409&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3730749e4ee5c329f7bb914e57cc3409 = L.map(
#                 &quot;map_3730749e4ee5c329f7bb914e57cc3409&quot;,
#                 {
#                     center: [12.943860555628737, 77.64203857962248],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_604df17c91c26524831939956cb3fd5e = L.tileLayer(
#                 &quot;http://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by CartoDB, under CC BY 3.0. Data by OpenStreetMap, under ODbL.&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_604df17c91c26524831939956cb3fd5e.addTo(map_3730749e4ee5c329f7bb914e57cc3409);
#
#
#             var marker_b43703411b7b8c9acfdd24028e9a0627 = L.marker(
#                 [12.929233, 77.627586],
#                 {}
#             ).addTo(map_3730749e4ee5c329f7bb914e57cc3409);
#
#
#             var icon_21c69e3673d3fe604e1051c2aaecdf7e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b43703411b7b8c9acfdd24028e9a0627.setIcon(icon_21c69e3673d3fe604e1051c2aaecdf7e);
#
#
#         var popup_082a646baff228bfb00085b1b63519d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7df29a09368e494eba00bdd39d3e8096 = $(`&lt;div id=&quot;html_7df29a09368e494eba00bdd39d3e8096&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;708.0&lt;/div&gt;`)[0];
#                 popup_082a646baff228bfb00085b1b63519d7.setContent(html_7df29a09368e494eba00bdd39d3e8096);
#
#
#
#         marker_b43703411b7b8c9acfdd24028e9a0627.bindPopup(popup_082a646baff228bfb00085b1b63519d7)
#         ;
#
#
#
#
#             var poly_line_562f53bf0813e6353c522d64c2b7f424 = L.polyline(
#                 [[12.929233, 77.627586], [12.928983, 77.627552], [12.929064, 77.627146], [12.93035, 77.627611], [12.930606, 77.624842], [12.931541, 77.622498], [12.934585, 77.623801], [12.935241, 77.624371], [12.937583, 77.62723], [12.938172, 77.628282], [12.938538, 77.629377], [12.938573, 77.632689], [12.9387, 77.632617], [12.938931, 77.632809], [12.94069, 77.632177], [12.941045, 77.63219], [12.941282, 77.63233], [12.942003, 77.633678], [12.946368, 77.635873], [12.947024, 77.636019], [12.947203, 77.636428], [12.94468, 77.642769], [12.943669, 77.642442]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_3730749e4ee5c329f7bb914e57cc3409);
#
#
#             var marker_6c9690ab586a900e9e74f1d716b287b0 = L.marker(
#                 [12.950838, 77.617045],
#                 {}
#             ).addTo(map_3730749e4ee5c329f7bb914e57cc3409);
#
#
#             var icon_3d56eb03e8b354901e30675e2d3aef7e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6c9690ab586a900e9e74f1d716b287b0.setIcon(icon_3d56eb03e8b354901e30675e2d3aef7e);
#
#
#         var popup_7a07961379ee1f12a11b016fc0d1674c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b81181d201c6f5d40cb4f56de5ce08fa = $(`&lt;div id=&quot;html_b81181d201c6f5d40cb4f56de5ce08fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;753.8&lt;/div&gt;`)[0];
#                 popup_7a07961379ee1f12a11b016fc0d1674c.setContent(html_b81181d201c6f5d40cb4f56de5ce08fa);
#
#
#
#         marker_6c9690ab586a900e9e74f1d716b287b0.bindPopup(popup_7a07961379ee1f12a11b016fc0d1674c)
#         ;
#
#
#
#
#             var poly_line_9e0bc2c595f10562b572c9c63c10184b = L.polyline(
#                 [[12.929233, 77.627586], [12.928983, 77.627552], [12.929064, 77.627146], [12.93035, 77.627611], [12.930606, 77.624842], [12.931541, 77.622498], [12.934585, 77.623801], [12.935241, 77.624371], [12.937583, 77.62723], [12.938172, 77.628282], [12.938538, 77.629377], [12.938573, 77.632689], [12.9387, 77.632617], [12.938931, 77.632809], [12.94069, 77.632177], [12.941045, 77.63219], [12.941282, 77.63233], [12.942003, 77.633678], [12.946368,

# %% [markdown]
# ### Commute Analysis

# %%
results1 = commute_analysis(combined_df1, 'First Choice')

# %%
results2 = commute_analysis(combined_df2, 'the other one')

# %%
# prompt: concat two dfs (add column)

shared_column = results1.columns[0]

# Concatenate the DataFrames
result = pd.concat([results1, results2.drop(columns=[shared_column])], axis=1)

result
# Out:
#                                  Measure  For First Choice  For the other one
# 0          total time (minutes each day)            308.07             570.32
# 1            mean time (minutes one way)             15.40              28.52
# 2          median time (minutes one way)             16.52              30.15
# 3    total distance (kilometers one way)             53.94              74.15
# 4             mean distance (kilometers)              5.39               7.42
# 5           median distance (kilometers)              5.63               8.06
# 6         total emissions (kgs per year)           1524.03            1876.90
# 7  emissions error margin (kgs per year)            152.40             187.69

# %% [markdown]
# ### Location Specific Bar Graphs

# %%
combined_df = pd.concat([df, routes_df], axis=1)
combined_df.reset_index(drop=True, inplace=True)
# combined_df.head()

# %%
# see all 22 variables under More Information, plus time and distance values in the combined_df
categories = "Department"
value = "Age"
for_title = "Geographic Center"
make_bargraph_for_this_center(combined_df, categories , value, for_title)

# %% [markdown]
# ## Clustering Tools

# %% [markdown]
# ### Center of Mass by Category

# %%
coms_map = plot_by_category(df, "Level", geocenter, 12, 'clean')
coms_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_033e4a707135589a7a40c4ecffc9d16c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position: fixed; bottom: 50px; left: 50px; width: 300px; height: 120px;
#     border:2px solid grey; z-index:9999; font-size:14px;
#     &quot;&gt;&amp;nbsp;&lt;b&gt;Legend&lt;/b&gt;&lt;br&gt;
#     &amp;nbsp;&lt;i class=&#x27;fa fa-map-marker fa-2x&#x27; style=&#x27;color:cadetblue&#x27;&gt;&lt;/i&gt;&amp;nbsp;Non executive&lt;br&gt;&amp;nbsp;&lt;i class=&#x27;fa fa-map-marker fa-2x&#x27; style=&#x27;color:lightblue&#x27;&gt;&lt;/i&gt;&amp;nbsp;Mid level executive or manager&lt;br&gt;&amp;nbsp;&lt;i class=&#x27;fa fa-map-marker fa-2x&#x27; style=&#x27;color:beige&#x27;&gt;&lt;/i&gt;&amp;nbsp;Upper level executive, VP, etc.&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_033e4a707135589a7a40c4ecffc9d16c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_033e4a707135589a7a40c4ecffc9d16c = L.map(
#                 &quot;map_033e4a707135589a7a40c4ecffc9d16c&quot;,
#                 {
#                     center: [12.937899282876856, 77.62113070481908],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd695dbeeb1d0143103b80ad2ec56d9d = L.tileLayer(
#                 &quot;http://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by CartoDB, under CC BY 3.0. Data by OpenStreetMap, under ODbL.&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bd695dbeeb1d0143103b80ad2ec56d9d.addTo(map_033e4a707135589a7a40c4ecffc9d16c);
#
#
#             var marker_d458a6a0cde3900d4879a1b580ba2b8f = L.marker(
#                 [12.929219184155466, 77.62771079999999],
#                 {}
#             ).addTo(map_033e4a707135589a7a40c4ecffc9d16c);
#
#
#             var icon_9f7622e18c098b034adab5b914a95c28 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d458a6a0cde3900d4879a1b580ba2b8f.setIcon(icon_9f7622e18c098b034adab5b914a95c28);
#
#
#         var popup_7ab9c28a1a8cd4684d6edd7f5df6404f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b1ec7617bd62d2891d0b4b158cdfaacd = $(`&lt;div id=&quot;html_b1ec7617bd62d2891d0b4b158cdfaacd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Level: Non executive&lt;/div&gt;`)[0];
#                 popup_7ab9c28a1a8cd4684d6edd7f5df6404f.setContent(html_b1ec7617bd62d2891d0b4b158cdfaacd);
#
#
#
#         marker_d458a6a0cde3900d4879a1b580ba2b8f.bindPopup(popup_7ab9c28a1a8cd4684d6edd7f5df6404f)
#         ;
#
#
#
#
#             var marker_6c9e2d1d6a110b9ed1f8a591f51ff952 = L.marker(
#                 [12.950795517102389, 77.61704047253774],
#                 {}
#             ).addTo(map_033e4a707135589a7a40c4ecffc9d16c);
#
#
#             var icon_430091e1c30a756d5b3a63c5336ddd82 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6c9e2d1d6a110b9ed1f8a591f51ff952.setIcon(icon_430091e1c30a756d5b3a63c5336ddd82);
#
#
#         var popup_0ed7e33eea854057b9e6664862e25135 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9744b6a782212446b6e6d21a71a5949d = $(`&lt;div id=&quot;html_9744b6a782212446b6e6d21a71a5949d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Level: Non executive&lt;/div&gt;`)[0];
#                 popup_0ed7e33eea854057b9e6664862e25135.setContent(html_9744b6a782212446b6e6d21a71a5949d);
#
#
#
#         marker_6c9e2d1d6a110b9ed1f8a591f51ff952.bindPopup(popup_0ed7e33eea854057b9e6664862e25135)
#         ;
#
#
#
#
#             var marker_0c00a83ce38c3b66139be241143bb2fa = L.marker(
#                 [12.940321422890475, 77.58458798397496],
#                 {}
#             ).addTo(map_033e4a707135589a7a40c4ecffc9d16c);
#
#
#             var icon_5d3edf26882c8545323fef85c454b318 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0c00a83ce38c3b66139be241143bb2fa.setIcon(icon_5d3edf26882c8545323fef85c454b318);
#
#
#         var popup_9097c50c9d8be7b81f17919d21317be3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f09eb0fbfd7deedeb5c53500db2888af = $(`&lt;div id=&quot;html_f09eb0fbfd7deedeb5c53500db2888af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Level: Non executi

# %% [markdown]
# ### K-Means

# %%
labels, centroids = Kmeans(points)
cluster_map = plot_clusters(points, geocenter, labels, centroids,'clean')
cluster_map
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36fba68f8ee11a115507270fc8de28cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36fba68f8ee11a115507270fc8de28cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36fba68f8ee11a115507270fc8de28cd = L.map(
#                 &quot;map_36fba68f8ee11a115507270fc8de28cd&quot;,
#                 {
#                     center: [12.938863738290344, 77.62039958313231],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a962d7d7cb5fd5639e3a9cbf9e65c280 = L.tileLayer(
#                 &quot;http://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by CartoDB, under CC BY 3.0. Data by OpenStreetMap, under ODbL.&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a962d7d7cb5fd5639e3a9cbf9e65c280.addTo(map_36fba68f8ee11a115507270fc8de28cd);
#
#
#             var marker_f655ab67b1dceee90b90ccc11ad9d7db = L.marker(
#                 [12.950795517102389, 77.61704047253774],
#                 {}
#             ).addTo(map_36fba68f8ee11a115507270fc8de28cd);
#
#
#             var icon_9aca66f43806eaa3937b0a391b0d04b8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f655ab67b1dceee90b90ccc11ad9d7db.setIcon(icon_9aca66f43806eaa3937b0a391b0d04b8);
#
#
#         var popup_8c7ff96ea5d9994bd8247a020dc3760a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4956c0c356f7303eb832138a0a5c366d = $(`&lt;div id=&quot;html_4956c0c356f7303eb832138a0a5c366d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;employee0&lt;/div&gt;`)[0];
#                 popup_8c7ff96ea5d9994bd8247a020dc3760a.setContent(html_4956c0c356f7303eb832138a0a5c366d);
#
#
#
#         marker_f655ab67b1dceee90b90ccc11ad9d7db.bindPopup(popup_8c7ff96ea5d9994bd8247a020dc3760a)
#         ;
#
#
#
#
#             var marker_db39da0f40d4aae0b970976474864cf9 = L.marker(
#                 [12.940321422890475, 77.58458798397496],
#                 {}
#             ).addTo(map_36fba68f8ee11a115507270fc8de28cd);
#
#
#             var icon_79d687cb1bd2f6ef371ba969dfb079c8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_db39da0f40d4aae0b970976474864cf9.setIcon(icon_79d687cb1bd2f6ef371ba969dfb079c8);
#
#
#         var popup_207ef083f2fadb5efaf415047226df6a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_420c4a02666ce3dee7604d4577795fa6 = $(`&lt;div id=&quot;html_420c4a02666ce3dee7604d4577795fa6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;employee1&lt;/div&gt;`)[0];
#                 popup_207ef083f2fadb5efaf415047226df6a.setContent(html_420c4a02666ce3dee7604d4577795fa6);
#
#
#
#         marker_db39da0f40d4aae0b970976474864cf9.bindPopup(popup_207ef083f2fadb5efaf415047226df6a)
#         ;
#
#
#
#
#             var marker_b65a4705577f4b2e95445ffacd43778e = L.marker(
#                 [12.904480264661224, 77.60113032392418],
#                 {}
#             ).addTo(map_36fba68f8ee11a115507270fc8de28cd);
#
#
#             var icon_166ddf8ae29d688bac64b4ff4c3151db = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b65a4705577f4b2e95445ffacd43778e.setIcon(icon_166ddf8ae29d688bac64b4ff4c3151db);
#
#
#         var popup_33c2d63351c5b6e90c44018db68d0ab9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b371253831850a80e91a74c5446166e4 = $(`&lt;div id=&quot;html_b371253831850a80e91a74c5446166e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;employee2&lt;/div&gt;`)[0];
#                 popup_33c2d63351c5b6e90c44018db68d0ab9.setContent(html_b371253831850a80e91a74c5446166e4);
#
#
#
#         marker_b65a4705577f4b2e95445ffacd43778e.bindPopup(popup_33c2d63351c5b6e90c44018db68d0ab9)
#         ;
#
#
#
#
#             var marker_7d05899d43a3082d9433ca2fd6419fc5 = L.marker(
#                 [12.964452253042428, 77.647491021871],
#                 {}
#             ).addTo(map_36fba68f8ee11a115507270fc8de28cd);
#
#
#             var icon_0091a665fa38707a2e34d30afb715efa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quo

# %% [markdown]
# ### Weighted K-Means

# %%
weights = [2,1,1,1,1,1,1,1,1]

n_clusters = 2
max_iterations = 5
n_repetitions = 5

labels, centroids = claudes_weighted_kmeans(points,weights,n_clusters, max_iterations, n_repetitions, standard_distance)
cluster_map = plot_clusters(points, center, labels, centroids,'clean')
cluster_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_789d01149c65f831c74854add5d1905f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_789d01149c65f831c74854add5d1905f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_789d01149c65f831c74854add5d1905f = L.map(
#                 &quot;map_789d01149c65f831c74854add5d1905f&quot;,
#                 {
#                     center: [12.938863738290344, 77.62039958313231],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_16bac74299eaf31f436be43c705a024c = L.tileLayer(
#                 &quot;http://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by CartoDB, under CC BY 3.0. Data by OpenStreetMap, under ODbL.&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_16bac74299eaf31f436be43c705a024c.addTo(map_789d01149c65f831c74854add5d1905f);
#
#
#             var marker_72d201b81ef81d4e526dafe8175f49ab = L.marker(
#                 [12.950795517102389, 77.61704047253774],
#                 {}
#             ).addTo(map_789d01149c65f831c74854add5d1905f);
#
#
#             var icon_9471fd2968817843c97bc67828179f7b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_72d201b81ef81d4e526dafe8175f49ab.setIcon(icon_9471fd2968817843c97bc67828179f7b);
#
#
#         var popup_eae2d424b9fa3f5b55fb78a1e1c13bea = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bf04e4cbaeb61b20ec240d4308992ab5 = $(`&lt;div id=&quot;html_bf04e4cbaeb61b20ec240d4308992ab5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;employee0&lt;/div&gt;`)[0];
#                 popup_eae2d424b9fa3f5b55fb78a1e1c13bea.setContent(html_bf04e4cbaeb61b20ec240d4308992ab5);
#
#
#
#         marker_72d201b81ef81d4e526dafe8175f49ab.bindPopup(popup_eae2d424b9fa3f5b55fb78a1e1c13bea)
#         ;
#
#
#
#
#             var marker_e47bef370ad608b45e06e2dd8c8fc3f6 = L.marker(
#                 [12.940321422890475, 77.58458798397496],
#                 {}
#             ).addTo(map_789d01149c65f831c74854add5d1905f);
#
#
#             var icon_1f23792b5edda569d6b5575a019dd45f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e47bef370ad608b45e06e2dd8c8fc3f6.setIcon(icon_1f23792b5edda569d6b5575a019dd45f);
#
#
#         var popup_b9d7784bdb122f1aa77d267781bc9817 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_62a2a33a07116fe5686d9a3b385da4fc = $(`&lt;div id=&quot;html_62a2a33a07116fe5686d9a3b385da4fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;employee1&lt;/div&gt;`)[0];
#                 popup_b9d7784bdb122f1aa77d267781bc9817.setContent(html_62a2a33a07116fe5686d9a3b385da4fc);
#
#
#
#         marker_e47bef370ad608b45e06e2dd8c8fc3f6.bindPopup(popup_b9d7784bdb122f1aa77d267781bc9817)
#         ;
#
#
#
#
#             var marker_2f5e3556b40f1d57bb1b919428146163 = L.marker(
#                 [12.904480264661224, 77.60113032392418],
#                 {}
#             ).addTo(map_789d01149c65f831c74854add5d1905f);
#
#
#             var icon_8f7d72cf81dd5642a38427b3c7a6fee4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2f5e3556b40f1d57bb1b919428146163.setIcon(icon_8f7d72cf81dd5642a38427b3c7a6fee4);
#
#
#         var popup_ab9b7da44861ab2efd6a33cf0cc28e75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0f2be49838e264e597c45470c323cdd7 = $(`&lt;div id=&quot;html_0f2be49838e264e597c45470c323cdd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;employee2&lt;/div&gt;`)[0];
#                 popup_ab9b7da44861ab2efd6a33cf0cc28e75.setContent(html_0f2be49838e264e597c45470c323cdd7);
#
#
#
#         marker_2f5e3556b40f1d57bb1b919428146163.bindPopup(popup_ab9b7da44861ab2efd6a33cf0cc28e75)
#         ;
#
#
#
#
#             var marker_37e6639a013e6c08042b482467c144f8 = L.marker(
#                 [12.964452253042428, 77.647491021871],
#                 {}
#             ).addTo(map_789d01149c65f831c74854add5d1905f);
#
#
#             var icon_2a23fdfa977ed65c5c3797c184ab3837 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot

# %% [markdown]
# # More Information and Tests

# %% [markdown]
# ## About the code

# %% [markdown]
# route_infos is an ordered list of dicts, each with geometry, time, and dist
#
#
# to access the latitude of the second point in the third route:
#
#
# routes_df['geometry'][2]['coordinates'][1][0]

# %% [markdown]
# ## About the data

# %% [markdown]
# ```
# Column Names
#
# Index -- Feature Name
# 0,Time
# 1,Level
# 2,Department
# 3,Years w/ Company
# 4,Lat and Long
# 5,Pincode
# 6,Commute Time
# 7,Commute Method
# 8,Age
# 9,Gender
# 10,Marraige
# 11,Children
# 12,Residence
# 13,Daycare Preference
# 14,Shifting Preference
# 15,Pincode Preference
# 16,Salary / WFO Preference
# 17,Managed by Indiqube?
# 18,Indiqube Rating
# 19,Frequency of app
# 20,Usefulness of app
# 21,Sentiment
# 22,Suggestions
# ```

# %% [markdown]
# ```
# Survey Questions:
#
# Timestamp
# Level
# What department are you in?
# "How many years have you been with the company? For more detail, please use decimals. For example 3.5 (no need to write years). "
# Latitude and Longitude
# What is you pincode? (optional)
# "How long, in minutes, is your current commute on average? Please enter only numbers"
# How do you commute?
# What is your age?
# What is your gender?
# Are you married?
# How many children do you have?
# Which do you live in?
# Is having daycares / schools near your office important to you?
# "If your office considered shifting, would you like to stay living where you are? "
# Please enter the pincode of where you would like to live (optional)
# Would you prefer salary raises or more work from home option?
# Is your current office space managed by Indiqube?
# "In your opinion, does your current Indiqube workplace provide an overall better employee experience than your last office space? (services provided, cleanliness, attractiveness of space, etc.) "
# How often do you use the MiQube app?
# How useful do you find the MiQube app?
# Write down any words you associate with Indiqube. (optional)
# Do you have an feedback or suggestions for Indiqube? (optional)
#
#
# ```

# %% [markdown]
# ## Tests

# %% [markdown]
# ### Test OSRM requests

# %%
# TEST 2 points
# Test Requests are working. The time between these 2 points should be 4591.4 seconds
## this shouldn't take more than a few seconds to run
waypoints_str = '77.62771079999999,12.929219184155466;77.61704047253774,12.950795517102389'

url = f"http://router.project-osrm.org/route/v1/driving/{waypoints_str}?geometries=geojson"


  # Make the request
response = requests.get(url)
if response.status_code != 200:
     raise Exception(f"Error: Received response code {response.status_code} from OSRM server")

data = response.json()

  # Extract the route duration
if 'routes' in data:
      routeinfo = data['routes']
      if routeinfo and 'geometry' in routeinfo[0]:
          time = routeinfo[0]['distance']
          geometry = routeinfo[0]['geometry']
          distance = routeinfo[0]['distance']

      else:
          print("These locations might be seperated by an ocean")
else:
      print("OSRM may be having problems returning any information")

print(time)
print(distance)
routes = []
routes.append(geometry['coordinates'])
map = folium.Map(location=(12.929219184155466,77.62771079999999), zoom_start=10)
map = add_routes(map,routes, "blue")
map
# Out:
# 4591.3
# 4591.3
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bb6689e2c5f61ce431791508acb2ec0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bb6689e2c5f61ce431791508acb2ec0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4bb6689e2c5f61ce431791508acb2ec0 = L.map(
#                 &quot;map_4bb6689e2c5f61ce431791508acb2ec0&quot;,
#                 {
#                     center: [12.929219184155466, 77.62771079999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c7ef8b608037eb275fb8d7b3cdb495a3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c7ef8b608037eb275fb8d7b3cdb495a3.addTo(map_4bb6689e2c5f61ce431791508acb2ec0);
#
#
#             var poly_line_ccfa95ec661c5edf08bbf8faa2982a56 = L.polyline(
#                 [[12.929233, 77.627586], [12.928983, 77.627552], [12.929064, 77.627146], [12.93035, 77.627611], [12.930606, 77.624842], [12.931541, 77.622498], [12.934965, 77.624072], [12.937281, 77.626874], [12.938183, 77.626158], [12.93985, 77.625365], [12.940405, 77.624888], [12.943875, 77.621166], [12.945827, 77.618568], [12.946308, 77.618626], [12.950708, 77.621077], [12.951662, 77.621386], [12.952438, 77.620162], [12.953772, 77.617363], [12.951242, 77.617029], [12.951154, 77.617643], [12.950859, 77.617358], [12.950838, 77.617045]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_4bb6689e2c5f61ce431791508acb2ec0);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
